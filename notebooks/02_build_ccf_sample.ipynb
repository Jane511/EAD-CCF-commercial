# %% [markdown]
# # Build CCF Sample
#
# Create a history-based CCF development sample when `facility_balance_history.csv` is available. Otherwise an empty sample file is created and the module stays rule-based.

# %%
from pathlib import Path
import sys

project_root = Path('..').resolve()
sys.path.append(str(project_root / 'src'))

from build_ccf_sample import main

main()
