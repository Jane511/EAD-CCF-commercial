# %% [markdown]
# # Calculate EAD
#
# Calculate central and downturn EAD using the assigned CCF values.

# %%
from pathlib import Path
import sys

project_root = Path('..').resolve()
sys.path.append(str(project_root / 'src'))

from calculate_ead import main

main()
