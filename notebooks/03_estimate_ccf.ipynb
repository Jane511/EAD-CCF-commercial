# %% [markdown]
# # Estimate CCF
#
# Assign central and downturn CCF using the manual rule table and simple utilisation or stage adjustments.

# %%
from pathlib import Path
import sys

project_root = Path('..').resolve()
sys.path.append(str(project_root / 'src'))

from estimate_ccf import main

main()
