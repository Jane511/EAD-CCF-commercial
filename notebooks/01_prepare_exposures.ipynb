# %% [markdown]
# # Prepare Exposures
#
# Clean, standardise, classify facilities, and calculate undrawn limit plus utilisation.

# %%
from pathlib import Path
import sys

project_root = Path('..').resolve()
sys.path.append(str(project_root / 'src'))

from prepare_exposures import main

main()
